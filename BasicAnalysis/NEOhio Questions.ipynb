# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

plt.style.use('seaborn-colorblind')

# %%
## Read in Excel files of data and question labels
XLS = pd.ExcelFile('../../ComputationSurveyData/LabeledComputationDataColumnRenamed.xlsx')
XLS2 = pd.ExcelFile('../../ComputationSurveyData/Questions.xlsx')

## Parse the appropriate sheets into dataframes
df = XLS.parse('LabeledComputationData')
questions = XLS2.parse('Sheet1')

outDir = "/Users/caballero/Repos/research/papers/2017_CompSurvey/Analysis/figs/"

# %%
## Apply lambda to count number of yeses
isY = lambda x:int(x==1) ## Relabeled yes as 1 and no as 0
countComputing = lambda row: isY(row.Q1)

numberTeachingComp = df.apply(countComputing,axis=1).sum()
numberRespondents = df.shape[0]
print('Number of total respondents: ', numberRespondents)
print('Number of those teaching computing: ', numberTeachingComp)

teachComp = numberTeachingComp/numberRespondents*100

fig1 = plt.figure(num=None, figsize=(4, 3), dpi=150, facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

plt.bar([0],[teachComp])
plt.bar([1],[100-teachComp])
plt.ylabel('% of Respondents')
plt.xticks([0,1],['Yes','No'])
plt.axis([-.5,1.5,0,100])
plt.title('Do you teach computing?')

bboxprops = {'facecolor':'white', 'pad':0.5, 'boxstyle':'round', 'edgecolor':'lightgrey', 'alpha':0.7}

ax1.text(0.95, 85, 'N = 1256', bbox = bboxprops)
Ystring = 'N = '+  str(numberTeachingComp)
ax1.text(-0.20, 10, Ystring, bbox=bboxprops)
Nstring = 'N = '+  str(numberRespondents-numberTeachingComp)
ax1.text(0.85, 10, Nstring, bbox=bboxprops)
plt.tight_layout()
#plt.savefig(outDir + 'TotalComp.pdf')
# Out:
# Number of total respondents:  1246
# Number of those teaching computing:  751

# %%
## Apply lambda to count number of yeses
isY = lambda x:int(x==1) ## Relabeled yes as 1 and no as 0
countComputing = lambda row: isY(row.Q2)

numberTeachingComp = df.apply(countComputing,axis=1).sum()
numberRespondents = df.shape[0]
print('Number of total respondents: ', numberRespondents)
print('Number of those teaching computing: ', numberTeachingComp)

teachComp = numberTeachingComp/numberRespondents*100

fig1 = plt.figure(num=None, figsize=(4, 3), dpi=150, facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

plt.bar([0],[teachComp])
plt.bar([1],[100-teachComp])
plt.ylabel('% of Respondents')
plt.xticks([0,1],['Yes','No'])
plt.axis([-.5,1.5,0,100])
plt.title('Do you have a major in\n in computational physics?')

bboxprops = {'facecolor':'white', 'pad':0.5, 'boxstyle':'round', 'edgecolor':'lightgrey', 'alpha':0.7}

ax1.text(0.95, 85, 'N = 1256', bbox = bboxprops)
Ystring = 'N = '+  str(numberTeachingComp)
ax1.text(-0.20, 10, Ystring, bbox=bboxprops)
Nstring = 'N = '+  str(numberRespondents-numberTeachingComp)
ax1.text(0.85, 10, Nstring, bbox=bboxprops)
plt.tight_layout()
#plt.savefig(outDir + 'TotalComp.pdf')
# Out:
# Number of total respondents:  1246
# Number of those teaching computing:  82

# %%
## Apply lambda to count number of yeses
isY = lambda x:int(x==1) ## Relabeled yes as 1 and no as 0
countComputing = lambda row: isY(row.Q3)

numberTeachingComp = df.apply(countComputing,axis=1).sum()
numberRespondents = df.shape[0]
print('Number of total respondents: ', numberRespondents)
print('Number of those teaching computing: ', numberTeachingComp)

teachComp = numberTeachingComp/numberRespondents*100

fig1 = plt.figure(num=None, figsize=(4, 3), dpi=150, facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

plt.bar([0],[teachComp])
plt.bar([1],[100-teachComp])
plt.ylabel('% of Respondents')
plt.xticks([0,1],['Yes','No'])
plt.axis([-.5,1.5,0,100])
plt.title('Do you have a minor in\n in computational physics?')

bboxprops = {'facecolor':'white', 'pad':0.5, 'boxstyle':'round', 'edgecolor':'lightgrey', 'alpha':0.7}

ax1.text(0.95, 85, 'N = 1256', bbox = bboxprops)
Ystring = 'N = '+  str(numberTeachingComp)
ax1.text(-0.20, 10, Ystring, bbox=bboxprops)
Nstring = 'N = '+  str(numberRespondents-numberTeachingComp)
ax1.text(0.85, 10, Nstring, bbox=bboxprops)
plt.tight_layout()
#plt.savefig(outDir + 'TotalComp.pdf')
# Out:
# Number of total respondents:  1246
# Number of those teaching computing:  29

# %%
## Apply lambda to count number of yeses
isY = lambda x:int(x==1) ## Relabeled yes as 1 and no as 0
countComputing = lambda row: isY(row.Q4)

numberTeachingComp = df.apply(countComputing,axis=1).sum()
numberRespondents = df.shape[0]
print('Number of total respondents: ', numberRespondents)
print('Number of those teaching computing: ', numberTeachingComp)

teachComp = numberTeachingComp/numberRespondents*100

fig1 = plt.figure(num=None, figsize=(4, 3), dpi=150, facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

plt.bar([0],[teachComp])
plt.bar([1],[100-teachComp])
plt.ylabel('% of Respondents')
plt.xticks([0,1],['Yes','No'])
plt.axis([-.5,1.5,0,100])
plt.title('Do you have a certificate in\n in computational physics?')

bboxprops = {'facecolor':'white', 'pad':0.5, 'boxstyle':'round', 'edgecolor':'lightgrey', 'alpha':0.7}

ax1.text(0.95, 85, 'N = 1256', bbox = bboxprops)
Ystring = 'N = '+  str(numberTeachingComp)
ax1.text(-0.20, 10, Ystring, bbox=bboxprops)
Nstring = 'N = '+  str(numberRespondents-numberTeachingComp)
ax1.text(0.85, 10, Nstring, bbox=bboxprops)
plt.tight_layout()
#plt.savefig(outDir + 'TotalComp.pdf')
# Out:
# Number of total respondents:  1246
# Number of those teaching computing:  15

# %%
df.groupby(['NAME'])['Q2'].describe()
# Out:
#                                                 count        mean         std  \
# NAME
# Alabama A & M University                          1.0   99.000000         NaN
# Albright College                                  1.0    0.000000         NaN
# Alfred University                                 3.0    0.333333    0.577350
# Allan Hancock College                             2.0   49.500000   70.003571
# Allegany College of Maryland                      1.0   99.000000         NaN
# Amarillo College                                  1.0   99.000000         NaN
# American University                               4.0   25.250000   49.168927
# Amherst College                                   6.0   16.500000   40.416581
# Andrews University                                2.0    0.000000    0.000000
# Antelope Valley College                           1.0    0.000000         NaN
# Appalachian State University                     11.0   27.181818   46.127688
# Arapahoe Community College                        1.0    0.000000         NaN
# Arkansas State University-Mountain Home           1.0   99.000000         NaN
# Arkansas Tech University                          2.0    0.000000    0.000000
# Asheville-Buncombe Technical Community College    2.0   99.000000    0.000000
# Ashland University                                1.0    0.000000         NaN
# Ave Maria University                              2.0   49.500000   70.003571
# Bakersfield College                               1.0    0.000000         NaN
# Benedict College                                  1.0   99.000000         NaN
# Bergen Community College                          4.0   24.750000   49.500000
# Big Bend Community College                        1.0   99.000000         NaN
# Black Hawk College                                1.0   99.000000         NaN
# Bob Jones University                              2.0   99.000000    0.000000
# Boston University                                 7.0   42.571429   52.785279
# Bowdoin College                                   6.0   33.166667   50.995751
# Bowling Green State University-Main Campus        5.0   59.400000   54.224533
# Bridgewater College                               3.0   33.666667   56.580326
# Bridgewater State University                      4.0   25.000000   49.335586
# Brookhaven College                                2.0   99.000000    0.000000
# Bryn Mawr College                                 4.0    0.000000    0.000000
# ...                                               ...         ...         ...
# University of South Alabama                       5.0   79.200000   44.274146
# University of Southern Mississippi                5.0   19.800000   44.274146
# University of Washington-Seattle Campus          35.0   59.428571   49.172736
# University of Wisconsin-La Crosse                 9.0   44.444444   51.756910
# University of Wisconsin-Whitewater                4.0   24.750000   49.500000
# University of Wyoming                             7.0  171.000000  368.084229
# University of the Pacific                         2.0    0.500000    0.707107
# Virginia Commonwealth University                  4.0   74.250000   49.500000
# Wagner College                                    1.0    0.000000         NaN
# Walla Walla University                            2.0   49.500000   70.003571
# Washburn University                               3.0   33.666667   56.580326
# Washington College                                3.0   33.000000   57.157677
# Washington State University                       6.0  199.500000  394.664794
# Washington University in St Louis                10.0   39.600000   51.123380
# Washtenaw Community College                       1.0    0.000000         NaN
# Wellesley College                                 8.0    0.125000    0.353553
# West Kentucky Community and Technical College     1.0    0.000000         NaN
# West Texas A & M University                       2.0   49.500000   70.003571
# Western Michigan University                       6.0   33.000000   51.123380
# Western Technical College-El Paso                 1.0   99.000000         NaN
# Westminster College-New Wilmington                1.0    0.000000         NaN
# Westmont College                                  1.0  999.000000         NaN
# Wheaton College-Norton                            4.0  274.500000  485.249420
# Wheeling Jesuit University                        1.0   99.000000         NaN
# Whitman College                                   4.0    0.000000    0.000000
# Whitworth University                              2.0   49.500000   70.003571
# Widener University-Main Campus                    2.0    0.000000    0.000000
# Wofford College                                   1.0    0.000000         NaN
# Xavier University of Louisiana                    5.0  219.600000  437.801667
# Youngstown State University                       6.0   33.000000   51.123380
#
#                                                   min     25%    50%     75%  \
# NAME
# Alabama A & M University                         99.0   99.00   99.0   99.00
# Albright College                                  0.0    0.00    0.0    0.00
# Alfred University                                 0.0    0.00    0.0    0.50
# Allan Hancock College                             0.0   24.75   49.5   74.25
# Allegany College of Maryland                     99.0   99.00   99.0   99.00
# Amarillo College                                 99.0   99.00   99.0   99.00
# American University                               0.0    0.75    1.0   25.50
# Amherst College                                   0.0    0.00    0.0    0.00
# Andrews University                                0.0    0.00    0.0    0.00
# Antelope Valley College                           0.0    0.00    0.0    0.00
# Appalachian State University                      0.0    0.00    0.0   50.00
# Arapahoe Community College                        0.0    0.00    0.0    0.00
# Arkansas State University-Mountain Home          99.0   99.00   99.0   99.00
# Arkansas Tech University                          0.0    0.00    0.0    0.00
# Asheville-Buncombe Technical Community College   99.0   99.00   99.0   99.00
# Ashland University                                0.0    0.00    0.0    0.00
# Ave Maria University                              0.0   24.75   49.5   74.25
# Bakersfield College                               0.0    0.00    0.0    0.00
# Benedict College                                 99.0   99.00   99.0   99.00
# Bergen Community College                          0.0    0.00    0.0   24.75
# Big Bend Community College                       99.0   99.00   99.0   99.00
# Black Hawk College                               99.0   99.00   99.0   99.00
# Bob Jones University                             99.0   99.00   99.0   99.00
# Boston University                                 0.0    0.00    1.0   99.00
# Bowdoin College                                   0.0    0.00    0.5   74.50
# Bowling Green State University-Main Campus        0.0    0.00   99.0   99.00
# Bridgewater College                               1.0    1.00    1.0   50.00
# Bridgewater State University                      0.0    0.00    0.5   25.50
# Brookhaven College                               99.0   99.00   99.0   99.00
# Bryn Mawr College                                 0.0    0.00    0.0    0.00
# ...                                               ...     ...    ...     ...
# University of South Alabama                       0.0   99.00   99.0   99.00
# University of Southern Mississippi                0.0    0.00    0.0    0.00
# University of Washington-Seattle Campus           0.0    0.00   99.0   99.00
# University of Wisconsin-La Crosse                 0.0    1.00    1.0   99.00
# University of Wisconsin-Whitewater                0.0    0.00    0.0   24.75
# University of Wyoming                             0.0    0.00    0.0   99.00
# University of the Pacific                         0.0    0.25    0.5    0.75
# Virginia Commonwealth University                  0.0   74.25   99.0   99.00
# Wagner College                                    0.0    0.00    0.0    0.00
# Walla Walla University                            0.0   24.75   49.5   74.25
# Washburn University                               1.0    1.00    1.0   50.00
# Washington College                                0.0    0.00    0.0   49.50
# Washington State University                       0.0    0.00   49.5   99.00
# Washington University in St Louis                 0.0    0.00    0.0   99.00
# Washtenaw Community College                       0.0    0.00    0.0    0.00
# Wellesley College                                 0.0    0.00    0.0    0.00
# West Kentucky Community and Technical College     0.0    0.00    0.0    0.00
# West Texas A & M University                       0.0   24.75   49.5   74.25
# Western Michigan University                       0.0    0.00    0.0   74.25
# Western Technical College-El Paso                99.0   99.00   99.0   99.00
# Westminster College-New Wilmington                0.0    0.00    0.0    0.00
# Westmont College                                999.0  999.00  999.0  999.00
# Wheaton College-Norton                            0.0    0.00   49.5  324.00
# Wheeling Jesuit University                       99.0   99.00   99.0   99.00
# Whitman College                                   0.0    0.00    0.0    0.00
# Whitworth University                              0.0   24.75   49.5   74.25
# Widener University-Main Campus                    0.0    0.00    0.0    0.00
# Wofford College                                   0.0    0.00    0.0    0.00
# Xavier University of Louisiana                    0.0    0.00    0.0   99.00
# Youngstown State University                       0.0    0.00    0.0   74.25
#
#                                                   max
# NAME
# Alabama A & M University                         99.0
# Albright College                                  0.0
# Alfred University                                 1.0
# Allan Hancock College                            99.0
# Allegany College of Maryland                     99.0
# Amarillo College                                 99.0
# American University                              99.0
# Amherst College                                  99.0
# Andrews University                                0.0
# Antelope Valley College                           0.0
# Appalachian State University                     99.0
# Arapahoe Community College                        0.0
# Arkansas State University-Mountain Home          99.0
# Arkansas Tech University                          0.0
# Asheville-Buncombe Technical Community College   99.0
# Ashland University                                0.0
# Ave Maria University                             99.0
# Bakersfield College                               0.0
# Benedict College                                 99.0
# Bergen Community College                         99.0
# Big Bend Community College                       99.0
# Black Hawk College                               99.0
# Bob Jones University                             99.0
# Boston University                                99.0
# Bowdoin College                                  99.0
# Bowling Green State University-Main Campus       99.0
# Bridgewater College                              99.0
# Bridgewater State University                     99.0
# Brookhaven College                               99.0
# Bryn Mawr College                                 0.0
# ...                                               ...
# University of South Alabama                      99.0
# University of Southern Mississippi               99.0
# University of Washington-Seattle Campus          99.0
# University of Wisconsin-La Crosse                99.0
# University of Wisconsin-Whitewater               99.0
# University of Wyoming                           999.0
# University of the Pacific                         1.0
# Virginia Commonwealth University                 99.0
# Wagner College                                    0.0
# Walla Walla University                           99.0
# Washburn University                              99.0
# Washington College                               99.0
# Washington State University                     999.0
# Washington University in St Louis                99.0
# Washtenaw Community College                       0.0
# Wellesley College                                 1.0
# West Kentucky Community and Technical College     0.0
# West Texas A & M University                      99.0
# Western Michigan University                      99.0
# Western Technical College-El Paso                99.0
# Westminster College-New Wilmington                0.0
# Westmont College                                999.0
# Wheaton College-Norton                          999.0
# Wheeling Jesuit University                       99.0
# Whitman College                                   0.0
# Whitworth University                             99.0
# Widener University-Main Campus                    0.0
# Wofford College                                   0.0
# Xavier University of Louisiana                  999.0
# Youngstown State University                      99.0
#
# [357 rows x 8 columns]

# %%
countsBySchool = df.groupby(['NAME'])['Q2'].mean()
numberOfSchoolsWithOneTeacher = countsBySchool[(countsBySchool > 0) & (countsBySchool <= 1)].shape[0]
numberOfUniqueSchools = df['NAME'].nunique()

print('Number of Unique Schools: ', numberOfUniqueSchools)
print('Number of Schools with computational physics degree: ', numberOfSchoolsWithOneTeacher)

atLeastOne = numberOfSchoolsWithOneTeacher/numberOfUniqueSchools*100

fig3 = plt.figure(num=None, figsize=(4, 3), dpi=150, facecolor='w', edgecolor='k')
ax3 = fig3.add_subplot(111)

plt.bar([0],[atLeastOne])
plt.bar([1],[100-atLeastOne])


plt.axis([-.5,1.5,0,100])

plt.ylabel('% of Departments')
plt.xticks([0,1],['Yes','No'])
plt.title('Does your department have\n a computational physics degree?')

ax3.text(1, 85, 'N = 357', bbox = bboxprops)

Ystring = 'N = '+  str(numberOfSchoolsWithOneTeacher)
ax3.text(-0.20, 10, Ystring, bbox=bboxprops)
Nstring = 'N = '+  str(numberOfUniqueSchools-numberOfSchoolsWithOneTeacher)
ax3.text(0.85, 10, Nstring, bbox=bboxprops)

plt.tight_layout()
#plt.savefig(outDir + 'OnePerson.pdf')
# Out:
# Number of Unique Schools:  357
# Number of Schools with computational physics degree:  13

# %%
countsBySchool = df.groupby(['NAME'])['Q3'].mean()
numberOfSchoolsWithOneTeacher = countsBySchool[(countsBySchool > 0) & (countsBySchool <= 1)].shape[0]
numberOfUniqueSchools = df['NAME'].nunique()

print('Number of Unique Schools: ', numberOfUniqueSchools)
print('Number of Schools with computational minor: ', numberOfSchoolsWithOneTeacher)

atLeastOne = numberOfSchoolsWithOneTeacher/numberOfUniqueSchools*100

fig3 = plt.figure(num=None, figsize=(4, 3), dpi=150, facecolor='w', edgecolor='k')
ax3 = fig3.add_subplot(111)

plt.bar([0],[atLeastOne])
plt.bar([1],[100-atLeastOne])


plt.axis([-.5,1.5,0,100])

plt.ylabel('% of Departments')
plt.xticks([0,1],['Yes','No'])
plt.title('Does your department have\n a computational physics minor?')

ax3.text(1, 85, 'N = 357', bbox = bboxprops)

Ystring = 'N = '+  str(numberOfSchoolsWithOneTeacher)
ax3.text(-0.20, 10, Ystring, bbox=bboxprops)
Nstring = 'N = '+  str(numberOfUniqueSchools-numberOfSchoolsWithOneTeacher)
ax3.text(0.85, 10, Nstring, bbox=bboxprops)

plt.tight_layout()
#plt.savefig(outDir + 'OnePerson.pdf')
# Out:
# Number of Unique Schools:  357
# Number of Schools with computational minor:  9

# %%
countsBySchool = df.groupby(['NAME'])['Q4'].mean()
numberOfSchoolsWithOneTeacher = countsBySchool[(countsBySchool > 0) & (countsBySchool <= 1)].shape[0]
numberOfUniqueSchools = df['NAME'].nunique()

print('Number of Unique Schools: ', numberOfUniqueSchools)
print('Number of Schools with computational minor: ', numberOfSchoolsWithOneTeacher)

atLeastOne = numberOfSchoolsWithOneTeacher/numberOfUniqueSchools*100

fig3 = plt.figure(num=None, figsize=(4, 3), dpi=150, facecolor='w', edgecolor='k')
ax3 = fig3.add_subplot(111)

plt.bar([0],[atLeastOne])
plt.bar([1],[100-atLeastOne])


plt.axis([-.5,1.5,0,100])

plt.ylabel('% of Departments')
plt.xticks([0,1],['Yes','No'])
plt.title('Does your department offer\n a computational physics certificate?')

ax3.text(1, 85, 'N = 357', bbox = bboxprops)

Ystring = 'N = '+  str(numberOfSchoolsWithOneTeacher)
ax3.text(-0.20, 10, Ystring, bbox=bboxprops)
Nstring = 'N = '+  str(numberOfUniqueSchools-numberOfSchoolsWithOneTeacher)
ax3.text(0.85, 10, Nstring, bbox=bboxprops)

plt.tight_layout()
#plt.savefig(outDir + 'OnePerson.pdf')
# Out:
# Number of Unique Schools:  357
# Number of Schools with computational minor:  1
